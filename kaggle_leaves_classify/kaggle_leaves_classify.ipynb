# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ./drive/MyDrive/
# !git clone https://github.com/Yepgang/madedlwithcode.git
# !pwd
# Out:
# [Errno 2] No such file or directory: './drive/MyDrive/'
# /content/drive/MyDrive/madedlwithcode/kaggle_leaves_classify
# Cloning into 'madedlwithcode'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 1), reused 13 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.
# /content/drive/My Drive/madedlwithcode/kaggle_leaves_classify

# %%
# !pwd
# !ls
# Out:
# /content/drive/MyDrive/madedlwithcode/kaggle_leaves_classify
# classify-leaves.zip  kaggle_leaves_classify.ipynb

# %%
# !unzip "classify-leaves.zip"
# Out:
# Archive:  classify-leaves.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of classify-leaves.zip or
#         classify-leaves.zip.zip, and cannot find classify-leaves.zip.ZIP, period.

# %%
import torch
import torch.nn as nn
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from PIL import Image
import os
import matplotlib.pyplot as plt
import torchvision.models as models
# This is for the progress bar.
from tqdm import tqdm
import seaborn as sns

# %%
1232143546576578658

# %%
# %cd ../../../
# Out:
# /content/drive

# %%
cd /content
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !git clone https://github.com/Yepgang/madedlwithcode.git
# Out:
# Cloning into 'madedlwithcode'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 14 (delta 1), reused 13 (delta 0), pack-reused 0
# Unpacking objects: 100% (14/14), done.
